# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely import wkt
from shapely.geometry import Polygon, LineString, Point
from shapely.ops import unary_union
import networkx as nx

# %%
# Load window delay data
df = pd.read_csv('../ERC data/odmatrix_bytaxa_byT.csv')
display(df.head())
# Out:
#    Taxon  T    O05    D05  ndispl
# 0  Seals  1  77700  75541       2
# 1  Seals  1  77700  76259       1
# 2  Seals  1  77700  76260      12
# 3  Seals  1  77700  76261       9
# 4  Seals  1  77700  76262       4

# %% [markdown]
# Cargo los poligonos de las celdas. Se empieza contando en 90S 180W. Se numeran hacia arriva y hacia la izquierda. (puede que este criterio sea diferente al que ha usado jorge para numerar las suyas)

# %%
cells_df = pd.read_csv('../data/cellseez.csv', index_col=0)
cells_df['geometry'] = cells_df['geometry'].apply(wkt.loads)
cells_gdf = gpd.GeoDataFrame(cells_df, geometry='geometry', crs='epsg:4326')

cells_gdf
# Out:
#           Lat     Lon                                           geometry  \
# 0      -89.75 -179.75  POLYGON ((-180.00000 -90.00000, -179.50000 -90...
# 1      -89.25 -179.75  POLYGON ((-180.00000 -89.50000, -179.50000 -89...
# 2      -88.75 -179.75  POLYGON ((-180.00000 -89.00000, -179.50000 -89...
# 3      -88.25 -179.75  POLYGON ((-180.00000 -88.50000, -179.50000 -88...
# 4      -87.75 -179.75  POLYGON ((-180.00000 -88.00000, -179.50000 -88...
# ...       ...     ...                                                ...
# 259195  87.75  179.75  POLYGON ((179.50000 87.50000, 180.00000 87.500...
# 259196  88.25  179.75  POLYGON ((179.50000 88.00000, 180.00000 88.000...
# 259197  88.75  179.75  POLYGON ((179.50000 88.50000, 180.00000 88.500...
# 259198  89.25  179.75  POLYGON ((179.50000 89.00000, 180.00000 89.000...
# 259199  89.75  179.75  POLYGON ((179.50000 89.50000, 180.00000 89.500...
#
#            goodeez
# 0       Antarctica
# 1       Antarctica
# 2       Antarctica
# 3       Antarctica
# 4       Antarctica
# ...            ...
# 259195          -1
# 259196          -1
# 259197          -1
# 259198          -1
# 259199          -1
#
# [259200 rows x 4 columns]

# %%
# Load data 
int_to_eez = {} # eez dictionary
eez_to_int = {} # eez dictionary
with open("../data/eez_to_int.csv", "r") as f:  
    f.readline() # read header
    for line in f:
        elem = line.strip().split(";")
        int_to_eez[int(elem[1])] = elem[0]
        eez_to_int[elem[0]] = int(elem[1])

# int_to_species = {} # species dictionary
# with open("../data/species_to_int.csv", "r") as f:  
#     f.readline() # read header
#     for line in f:
#         elem = line.strip().split(";")
#         int_to_species[int(elem[1])] = elem[0]
eez_to_iso3 = {} # eez to iso3 dictionary
with open("../data/eez_to_iso3.csv", "r") as f:  
    f.readline() # read header
    for line in f:
        elem = line.strip().split(";")
        eez_to_iso3[elem[0]] = elem[1]

# %%
cells_to_eez = dict(zip(cells_gdf.index, cells_gdf['goodeez']))
cells_to_eez
# Out:
# {0: 'Antarctica',
#  1: 'Antarctica',
#  2: 'Antarctica',
#  3: 'Antarctica',
#  4: 'Antarctica',
#  5: 'Antarctica',
#  6: 'Antarctica',
#  7: 'Antarctica',
#  8: 'Antarctica',
#  9: 'Antarctica',
#  10: 'Antarctica',
#  11: 'Antarctica',
#  12: 'Antarctica',
#  13: 'Antarctica',
#  14: 'Antarctica',
#  15: 'Antarctica',
#  16: 'Antarctica',
#  17: 'Antarctica',
#  18: 'Antarctica',
#  19: 'Antarctica',
#  20: 'Antarctica',
#  21: 'Antarctica',
#  22: 'Antarctica',
#  23: 'Antarctica',
#  24: 'Antarctica',
#  25: 'Antarctica',
#  26: 'Antarctica',
#  27: 'Antarctica',
#  28: 'Antarctica',
#  29: 'Antarctica',
#  30: 'Antarctica',
#  31: 'Antarctica',
#  32: 'Antarctica',
#  33: 'Antarctica',
#  34: 'Antarctica',
#  35: 'Antarctica',
#  36: 'Antarctica',
#  37: 'Antarctica',
#  38: 'Antarctica',
#  39: 'Antarctica',
#  40: '-1',
#  41: '-1',
#  42: '-1',
#  43: '-1',
#  44: '-1',
#  45: '-1',
#  46: '-1',
#  47: '-1',
#  48: '-1',
#  49: '-1',
#  50: '-1',
#  51: '-1',
#  52: '-1',
#  53: '-1',
#  54: '-1',
#  55: '-1',
#  56: '-1',
#  57: '-1',
#  58: '-1',
#  59: '-1',
#  60: '-1',
#  61: '-1',
#  62: '-1',
#  63: '-1',
#  64: '-1',
#  65: '-1',
#  66: '-1',
#  67: '-1',
#  68: '-1',
#  69: '-1',
#  70: '-1',
#  71: '-1',
#  72: '-1',
#  73: '-1',
#  74: 'New Zealand',
#  75: 'New Zealand',
#  76: 'New Zealand',
#  77: 'New Zealand',
#  78: 'New Zealand',
#  79: 'New Zealand',
#  80: 'New Zealand',
#  81: 'New Zealand',
#  82: 'New Zealand',
#  83: 'New Zealand',
#  84: 'New Zealand',
#  85: 'New Zealand',
#  86: 'New Zealand',
#  87: 'New Zealand',
#  88: 'New Zealand',
#  89: 'New Zealand',
#  90: 'New Zealand',
#  91: 'New Zealand',
#  92: 'New Zealand',
#  93: 'New Zealand',
#  94: 'New Zealand',
#  95: 'New Zealand',
#  96: 'New Zealand',
#  97: 'New Zealand',
#  98: 'New Zealand',
#  99: 'New Zealand',
#  100: 'New Zealand',
#  101: 'New Zealand',
#  102: 'New Zealand',
#  103: 'New Zealand',
#  104: 'New Zealand',
#  105: 'New Zealand',
#  106: 'New Zealand',
#  107: 'New Zealand',
#  108: 'New Zealand',
#  109: 'New Zealand',
#  110: 'New Zealand',
#  111: 'New Zealand',
#  112: 'New Zealand',
#  113: 'New Zealand',
#  114: 'New Zealand',
#  115: 'New Zealand',
#  116: 'New Zealand',
#  117: 'New Zealand',
#  118: 'New Zealand',
#  119: 'New Zealand',
#  120: 'New Zealand',
#  121: 'New Zealand',
#  122: 'New Zealand',
#  123: 'New Zealand',
#  124: 'New Zealand',
#  125: 'New Zealand',
#  126: 'New Zealand',
#  127: 'New Zealand',
#  128: '-1',
#  129: '-1',
#  130: '-1',
#  131: 'Fiji',
#  132: 'Fiji',
#  133: 'Fiji',
#  134: 'Fiji',
#  135: 'Fiji',
#  136: 'Fiji',
#  137: 'Fiji',
#  138: 'Fiji',
#  139: 'Fiji',
#  140: 'Fiji',
#  141: 'Fiji',
#  142: 'Fiji',
#  143: 'Fiji',
#  144: 'Fiji',
#  145: 'Fiji',
#  146: 'Fiji',
#  147: 'Fiji',
#  148: 'Fiji',
#  149: 'Fiji',
#  150: 'Fiji',
#  151: 'Fiji',
#  152: 'Fiji',
#  153: 'Wallis & Futuna',
#  154: 'Tuvalu',
#  155: 'Tuvalu',
#  156: 'Tuvalu',
#  157: 'Tuvalu',
#  158: 'Tuvalu',
#  159: 'Tuvalu',
#  160: 'Tuvalu',
#  161: 'Tuvalu',
#  162: 'Tuvalu',
#  163: 'Tuvalu',
#  164: 'Tuvalu',
#  165: 'Tuvalu',
#  166: 'Tuvalu',
#  167: 'Tuvalu',
#  168: 'Tuvalu',
#  169: 'Tuvalu',
#  170: 'Tuvalu',
#  171: 'Tuvalu',
#  172: 'United States Minor Outlying Islands',
#  173: 'United States Minor Outlying Islands',
#  174: 'United States Minor Outlying Islands',
#  175: 'United States Minor Outlying Islands',
#  176: 'United States Minor Outlying Islands',
#  177: 'United States Minor Outlying Islands',
#  178: 'United States Minor Outlying Islands',
#  179: 'United States Minor Outlying Islands',
#  180: 'United States Minor Outlying Islands',
#  181: 'United States Minor Outlying Islands',
#  182: 'United States Minor Outlying Islands',
#  183: 'United States Minor Outlying Islands',
#  184: 'United States Minor Outlying Islands',
#  185: 'United States Minor Outlying Islands',
#  186: '-1',
#  187: '-1',
#  188: '-1',
#  189: '-1',
#  190: '-1',
#  191: '-1',
#  192: '-1',
#  193: '-1',
#  194: '-1',
#  195: '-1',
#  196: '-1',
#  197: '-1',
#  198: '-1',
#  199: '-1',
#  200: '-1',
#  201: '-1',
#  202: '-1',
#  203: '-1',
#  204: '-1',
#  205: '-1',
#  206: '-1',
#  207: '-1',
#  208: '-1',
#  209: '-1',
#  210: '-1',
#  211: '-1',
#  212: '-1',
#  213: '-1',
#  214: '-1',
#  215: '-1',
#  216: '-1',
#  217: '-1',
#  218: '-1',
#  219: '-1',
#  220: '-1',
#  221: '-1',
#  222: '-1',
#  223: '-1',
#  224: '-1',
#  225: '-1',
#  226: '-1',
#  227: '-1',
#  228: '-1',
#  229: '-1',
#  230: 'United States',
#  231: 'United States',
#  232: 'United States',
#  233: 'United States',
#  234: 'United States',
#  235: 'United States',
#  236: 'United States',
#  237: 'United States',
#  238: 'United States',
#  239: 'United States',
#  240: 'United States',
#  241: 'United States',
#  242: 'United States',
#  243: 'United States',
#  244: '-1',
#  245: '-1',
#  246: '-1',
#  247: '-1',
#  248: '-1',
#  249: '-1',
#  250: '-1',
#  251: '-1',
#  252: '-1',
#  253: '-1',
#  254: '-1',
#  255: '-1',
#  256: '-1',
#  257: '-1',
#  258: '-1',
#  259: '-1',
#  260: '-1',
#  261: '-1',
#  262: '-1',
#  263: '-1',
#  264: '-1',
#  265: '-1',
#  266: '-1',
#  267: '-1',
#  268: '-1',
#  269: '-1',
#  270: '-1',
#  271: '-1',
#  272: '-1',
#  273: '-1',
#  274: '-1',
#  275: 'United States',
#  276: 'United States',
#  277: 'United States',
#  278: 'United States',
#  279: 'United States',
#  280: 'United States',
#  281: 'United States',
#  282: 'United States',
#  283: 'United States',
#  284: 'United States',
#  285: 'United States',
#  286: 'United States',
#  287: 'United States',
#  288: 'United States',
#  289: 'United States',
#  290: 'United States',
#  291: '-1',
#  292: '-1',
#  293: '-1',
#  294: '-1',
#  295: '-1',
#  296: '-1',
#  297: '-1',
#  298: '-1',
#  299: 'United States',
#  300: 'United States',
#  301: 'Russia',
#  302: 'Russia',
#  303: 'Russia',
#  304: 'Russia',
#  305: 'Russia',
#  306: 'Russia',
#  307: 'Russia',
#  308: 'Russia',
#  309: 'Russia',
#  310: 'Russia',
#  311: 'Russia',
#  312: 'Russia',
#  313: 'Russia',
#  314: 'Russia',
#  315: 'Russia',
#  316: 'Russia',
#  317: 'Russia',
#  318: 'Russia',
#  319: 'Russia',
#  320: 'Russia',
#  321: 'Russia',
#  322: 'Russia',
#  323: 'Russia',
#  324: 'Russia',
#  325: 'Russia',
#  326: 'Russia',
#  327: 'Russia',
#  328: 'Russia',
#  329: 'Russia',
#  330: '-1',
#  331: '-1',
#  332: '-1',
#  333: '-1',
#  334: '-1',
#  335: '-1',
#  336: '-1',
#  337: '-1',
#  338: '-1',
#  339: '-1',
#  340: '-1',
#  341: '-1',
#  342: '-1',
#  343: '-1',
#  344: '-1',
#  345: '-1',
#  346: '-1',
#  347: '-1',
#  348: '-1',
#  349: '-1',
#  350: '-1',
#  351: '-1',
#  352: '-1',
#  353: '-1',
#  354: '-1',
#  355: '-1',
#  356: '-1',
#  357: '-1',
#  358: '-1',
#  359: '-1',
#  360: 'Antarctica',
#  361: 'Antarctica',
#  362: 'Antarctica',
#  363: 'Antarctica',
#  364: 'Antarctica',
#  365: 'Antarctica',
#  366: 'Antarctica',
#  367: 'Antarctica',
#  368: 'Antarctica',
#  369: 'Antarctica',
#  370: 'Antarctica',
#  371: 'Antarctica',
#  372: 'Antarctica',
#  373: 'Antarctica',
#  374: 'Antarctica',
#  375: 'Antarctica',
#  376: 'Antarctica',
#  377: 'Antarctica',
#  378: 'Antarctica',
#  379: 'Antarctica',
#  380: 'Antarctica',
#  381: 'Antarctica',
#  382: 'Antarctica',
#  383: 'Antarctica',
#  384: 'Antarctica',
#  385: 'Antarctica',
#  386: 'Antarctica',
#  387: 'Antarctica',
#  388: 'Antarctica',
#  389: 'Antarctica',
#  390: 'Antarctica',
#  391: 'Antarctica',
#  392: 'Antarctica',
#  393: 'Antarctica',
#  394: 'Antarctica',
#  395: 'Antarctica',
#  396: 'Antarctica',
#  397: 'Antarctica',
#  398: 'Antarctica',
#  399: 'Antarctica',
#  400: '-1',
#  401: '-1',
#  402: '-1',
#  403: '-1',
#  404: '-1',
#  405: '-1',
#  406: '-1',
#  407: '-1',
#  408: '-1',
#  409: '-1',
#  410: '-1',
#  411: '-1',
#  412: '-1',
#  413: '-1',
#  414: '-1',
#  415: '-1',
#  416: '-1',
#  417: '-1',
#  418: '-1',
#  419: '-1',
#  420: '-1',
#  421: '-1',
#  422: '-1',
#  423: '-1',
#  424: '-1',
#  425: '-1',
#  426: '-1',
#  427: '-1',
#  428: '-1',
#  429: '-1',
#  430: '-1',
#  431: '-1',
#  432: '-1',
#  433: '-1',
#  434: 'New Zealand',
#  435: 'New Zealand',
#  436: 'New Zealand',
#  437: 'New Zealand',
#  438: 'New Zealand',
#  439: 'New Zealand',
#  440: 'New Zealand',
#  441: 'New Zealand',
#  442: 'New Zealand',
#  443: 'New Zealand',
#  444: 'New Zealand',
#  445: 'New Zealand',
#  446: 'New Zealand',
#  447: 'New Zealand',
#  448: 'New Zealand',
#  449: 'New Zealand',
#  450: 'New Zealand',
#  451: 'New Zealand',
#  452: 'New Zealand',
#  453: 'New Zealand',
#  454: 'New Zealand',
#  455: 'New Zealand',
#  456: 'New Zealand',
#  457: 'New Zealand',
#  458: 'New Zealand',
#  459: 'New Zealand',
#  460: 'New Zealand',
#  461: 'New Zealand',
#  462: 'New Zealand',
#  463: 'New Zealand',
#  464: 'New Zealand',
#  465: 'New Zealand',
#  466: 'New Zealand',
#  467: 'New Zealand',
#  468: 'New Zealand',
#  469: 'New Zealand',
#  470: 'New Zealand',
#  471: 'New Zealand',
#  472: 'New Zealand',
#  473: 'New Zealand',
#  474: 'New Zealand',
#  475: 'New Zealand',
#  476: 'New Zealand',
#  477: 'New Zealand',
#  478: 'New Zealand',
#  479: 'New Zealand',
#  480: 'New Zealand',
#  481: 'New Zealand',
#  482: 'New Zealand',
#  483: 'New Zealand',
#  484: 'New Zealand',
#  485: 'New Zealand',
#  486: 'New Zealand',
#  487: 'New Zealand',
#  488: '-1',
#  489: '-1',
#  490: '-1',
#  491: 'Fiji',
#  492: 'Fiji',
#  493: 'Fiji',
#  494: 'Fiji',
#  495: 'Fiji',
#  496: 'Fiji',
#  497: 'Fiji',
#  498: 'Fiji',
#  499: 'Fiji',
#  500: 'Fiji',
#  501: 'Fiji',
#  502: 'Fiji',
#  503: 'Fiji',
#  504: 'Fiji',
#  505: 'Fiji',
#  506: 'Fiji',
#  507: 'Fiji',
#  508: 'Fiji',
#  509: 'Fiji',
#  510: 'Fiji',
#  511: 'Fiji',
#  512: 'Wallis & Futuna',
#  513: 'Wallis & Futuna',
#  514: 'Tuvalu',
#  515: 'Tuvalu',
#  516: 'Tuvalu',
#  517: 'Tuvalu',
#  518: 'Tuvalu',
#  519: 'Tuvalu',
#  520: 'Tuvalu',
#  521: 'Tuvalu',
#  522: 'Tuvalu',
#  523: 'Tuvalu',
#  524: 'Tuvalu',
#  525: 'Tuvalu',
#  526: 'Tuvalu',
#  527: 'Tuvalu',
#  528: 'Tuvalu',
#  529: 'Tuvalu',
#  530: 'Tuvalu',
#  531: '-1',
#  532: '-1',
#  533: '-1',
#  534: '-1',
#  535: 'United States Minor Outlying Islands',
#  536: 'United States Minor Outlying Islands',
#  537: 'United States Minor Outlying Islands',
#  538: 'United States Minor Outlying Islands',
#  539: 'United States Minor Outlying Islands',
#  540: 'United States Minor Outlying Islands',
#  541: 'United States Minor Outlying Islands',
#  542: 'United States Minor Outlying Islands',
#  543: 'United States Minor Outlying Islands',
#  544: 'United States Minor Outlying Islands',
#  545: 'United States Minor Outlying Islands',
#  546: 'United States Minor Outlying Islands',
#  547: '-1',
#  548: '-1',
#  549: '-1',
#  550: '-1',
#  551: '-1',
#  552: '-1',
#  553: '-1',
#  554: '-1',
#  555: '-1',
#  556: '-1',
#  557: '-1',
#  558: '-1',
#  559: '-1',
#  560: '-1',
#  561: '-1',
#  562: '-1',
#  563: '-1',
#  564: '-1',
#  565: '-1',
#  566: '-1',
#  567: '-1',
#  568: '-1',
#  569: '-1',
#  570: '-1',
#  571: '-1',
#  572: '-1',
#  573: '-1',
#  574: '-1',
#  575: '-1',
#  576: '-1',
#  577: '-1',
#  578: '-1',
#  579: '-1',
#  580: '-1',
#  581: '-1',
#  582: '-1',
#  583: '-1',
#  584: '-1',
#  585: '-1',
#  586: '-1',
#  587: '-1',
#  588: '-1',
#  589: '-1',
#  590: 'United States',
#  591: 'United States',
#  592: 'United States',
#  593: 'United States',
#  594: 'United States',
#  595: 'United States',
#  596: 'United States',
#  597: 'United States',
#  598: 'United States',
#  599: 'United States',
#  600: 'United States',
#  601: 'United States',
#  602: 'United States',
#  603: 'United States',
#  604: '-1',
#  605: '-1',
#  606: '-1',
#  607: '-1',
#  608: '-1',
#  609: '-1',
#  610: '-1',
#  611: '-1',
#  612: '-1',
#  613: '-1',
#  614: '-1',
#  615: '-1',
#  616: '-1',
#  617: '-1',
#  618: '-1',
#  619: '-1',
#  620: '-1',
#  621: '-1',
#  622: '-1',
#  623: '-1',
#  624: '-1',
#  625: '-1',
#  626: '-1',
#  627: '-1',
#  628: '-1',
#  629: '-1',
#  630: '-1',
#  631: '-1',
#  632: '-1',
#  633: '-1',
#  634: '-1',
#  635: 'United States',
#  636: 'United States',
#  637: 'United States',
#  638: 'United States',
#  639: 'United States',
#  640: 'United States',
#  641: 'United States',
#  642: 'United States',
#  643: 'United States',
#  644: 'United States',
#  645: 'United States',
#  646: 'United States',
#  647: 'United States',
#  648: 'United States',
#  649: 'United States',
#  650: 'United States',
#  651: '-1',
#  652: '-1',
#  653: '-1',
#  654: '-1',
#  655: '-1',
#  656: '-1',
#  657: '-1',
#  658: 'United States',
#  659: 'United States',
#  660: 'United States',
#  661: 'United States',
#  662: 'Russia',
#  663: 'Russia',
#  664: 'Russia',
#  665: 'Russia',
#  666: 'Russia',
#  667: 'Russia',
#  668: 'Russia',
#  669: 'Russia',
#  670: 'Russia',
#  671: 'Russia',
#  672: 'Russia',
#  673: 'Russia',
#  674: 'Russia',
#  675: 'Russia',
#  676: 'Russia',
#  677: 'Russia',
#  678: 'Russia',
#  679: 'Russia',
#  680: 'Russia',
#  681: 'Russia',
#  682: 'Russia',
#  683: 'Russia',
#  684: 'Russia',
#  685: 'Russia',
#  686: 'Russia',
#  687: 'Russia',
#  688: 'Russia',
#  689: 'Russia',
#  690: '-1',
#  691: '-1',
#  692: '-1',
#  693: '-1',
#  694: '-1',
#  695: '-1',
#  696: '-1',
#  697: '-1',
#  698: '-1',
#  699: '-1',
#  700: '-1',
#  701: '-1',
#  702: '-1',
#  703: '-1',
#  704: '-1',
#  705: '-1',
#  706: '-1',
#  707: '-1',
#  708: '-1',
#  709: '-1',
#  710: '-1',
#  711: '-1',
#  712: '-1',
#  713: '-1',
#  714: '-1',
#  715: '-1',
#  716: '-1',
#  717: '-1',
#  718: '-1',
#  719: '-1',
#  720: 'Antarctica',
#  721: 'Antarctica',
#  722: 'Antarctica',
#  723: 'Antarctica',
#  724: 'Antarctica',
#  725: 'Antarctica',
#  726: 'Antarctica',
#  727: 'Antarctica',
#  728: 'Antarctica',
#  729: 'Antarctica',
#  730: 'Antarctica',
#  731: 'Antarctica',
#  732: 'Antarctica',
#  733: 'Antarctica',
#  734: 'Antarctica',
#  735: 'Antarctica',
#  736: 'Antarctica',
#  737: 'Antarctica',
#  738: 'Antarctica',
#  739: 'Antarctica',
#  740: 'Antarctica',
#  741: 'Antarctica',
#  742: 'Antarctica',
#  743: 'Antarctica',
#  744: 'Antarctica',
#  745: 'Antarctica',
#  746: 'Antarctica',
#  747: 'Antarctica',
#  748: 'Antarctica',
#  749: 'Antarctica',
#  750: 'Antarctica',
#  751: 'Antarctica',
#  752: 'Antarctica',
#  753: 'Antarctica',
#  754: 'Antarctica',
#  755: 'Antarctica',
#  756: 'Antarctica',
#  757: 'Antarctica',
#  758: 'Antarctica',
#  759: '-1',
#  760: '-1',
#  761: '-1',
#  762: '-1',
#  763: '-1',
#  764: '-1',
#  765: '-1',
#  766: '-1',
#  767: '-1',
#  768: '-1',
#  769: '-1',
#  770: '-1',
#  771: '-1',
#  772: '-1',
#  773: '-1',
#  774: '-1',
#  775: '-1',
#  776: '-1',
#  777: '-1',
#  778: '-1',
#  779: '-1',
#  780: '-1',
#  781: '-1',
#  782: '-1',
#  783: '-1',
#  784: '-1',
#  785: '-1',
#  786: '-1',
#  787: '-1',
#  788: '-1',
#  789: '-1',
#  790: '-1',
#  791: '-1',
#  792: '-1',
#  793: '-1',
#  794: 'New Zealand',
#  795: 'New Zealand',
#  796: 'New Zealand',
#  797: 'New Zealand',
#  798: 'New Zealand',
#  799: 'New Zealand',
#  800: 'New Zealand',
#  801: 'New Zealand',
#  802: 'New Zealand',
#  803: 'New Zealand',
#  804: 'New Zealand',
#  805: 'New Zealand',
#  806: 'New Zealand',
#  807: 'New Zealand',
#  808: 'New Zealand',
#  809: 'New Zealand',
#  810: 'New Zealand',
#  811: 'New Zealand',
#  812: 'New Zealand',
#  813: 'New Zealand',
#  814: 'New Zealand',
#  815: 'New Zealand',
#  816: 'New Zealand',
#  817: 'New Zealand',
#  818: 'New Zealand',
#  819: 'New Zealand',
#  820: 'New Zealand',
#  821: 'New Zealand',
#  822: 'New Zealand',
#  823: 'New Zealand',
#  824: 'New Zealand',
#  825: 'New Zealand',
#  826: 'New Zealand',
#  827: 'New Zealand',
#  828: 'New Zealand',
#  829: 'New Zealand',
#  830: 'New Zealand',
#  831: 'New Zealand',
#  832: 'New Zealand',
#  833: 'New Zealand',
#  834: 'New Zealand',
#  835: 'New Zealand',
#  836: 'New Zealand',
#  837: 'New Zealand',
#  838: 'New Zealand',
#  839: 'New Zealand',
#  840: 'New Zealand',
#  841: 'New Zealand',
#  842: 'New Zealand',
#  843: 'New Zealand',
#  844: 'New Zealand',
#  845: 'New Zealand',
#  846: 'New Zealand',
#  847: 'New Zealand',
#  848: 'New Zealand',
#  849: '-1',
#  850: 'Tonga',
#  851: 'Fiji',
#  852: 'Fiji',
#  853: 'Fiji',
#  854: 'Fiji',
#  855: 'Fiji',
#  856: 'Fiji',
#  857: 'Fiji',
#  858: 'Fiji',
#  859: 'Fiji',
#  860: 'Fiji',
#  861: 'Fiji',
#  862: 'Fiji',
#  863: 'Fiji',
#  864: 'Fiji',
#  865: 'Fiji',
#  866: 'Fiji',
#  867: 'Fiji',
#  868: 'Fiji',
#  869: 'Fiji',
#  870: 'Fiji',
#  871: 'Wallis & Futuna',
#  872: 'Wallis & Futuna',
#  873: 'Wallis & Futuna',
#  874: 'Wallis & Futuna',
#  875: 'Tuvalu',
#  876: 'Tuvalu',
#  877: 'Tuvalu',
#  878: 'Tuvalu',
#  879: 'Tuvalu',
#  880: 'Tuvalu',
#  881: 'Tuvalu',
#  882: 'Tuvalu',
#  883: 'Tuvalu',
#  884: 'Tuvalu',
#  885: 'Tuvalu',
#  886: 'Tuvalu',
#  887: 'Tuvalu',
#  888: 'Tuvalu',
#  889: 'Tuvalu',
#  890: '-1',
#  891: '-1',
#  892: '-1',
#  893: '-1',
#  894: '-1',
#  895: 'United States Minor Outlying Islands',
#  896: 'United States Minor Outlying Islands',
#  897: 'United States Minor Outlying Islands',
#  898: 'United States Minor Outlying Islands',
#  899: 'United States Minor Outlying Islands',
#  900: 'United States Minor Outlying Islands',
#  901: 'United States Minor Outlying Islands',
#  902: 'United States Minor Outlying Islands',
#  903: 'United States Minor Outlying Islands',
#  904: 'United States Minor Outlying Islands',
#  905: 'United States Minor Outlying Islands',
#  906: 'United States Minor Outlying Islands',
#  907: 'United States Minor Outlying Islands',
#  908: '-1',
#  909: '-1',
#  910: '-1',
#  911: '-1',
#  912: '-1',
#  913: '-1',
#  914: '-1',
#  915: '-1',
#  916: '-1',
#  917: '-1',
#  918: '-1',
#  919: '-1',
#  920: '-1',
#  921: '-1',
#  922: '-1',
#  923: '-1',
#  924: '-1',
#  925: '-1',
#  926: '-1',
#  927: '-1',
#  928: '-1',
#  929: '-1',
#  930: '-1',
#  931: '-1',
#  932: '-1',
#  933: '-1',
#  934: '-1',
#  935: '-1',
#  936: '-1',
#  937: '-1',
#  938: '-1',
#  939: '-1',
#  940: '-1',
#  941: '-1',
#  942: '-1',
#  943: '-1',
#  944: '-1',
#  945: '-1',
#  946: '-1',
#  947: '-1',
#  948: '-1',
#  949: 'United States',
#  950: 'United States',
#  951: 'United States',
#  952: 'United States',
#  953: 'United States',
#  954: 'United States',
#  955: 'United States',
#  956: 'United States',
#  957: 'United States',
#  958: 'United States',
#  959: 'United States',
#  960: 'United States',
#  961: 'United States',
#  962: 'United States',
#  963: 'United States',
#  964: '-1',
#  965: '-1',
#  966: '-1',
#  967: '-1',
#  968: '-1',
#  969: '-1',
#  970: '-1',
#  971: '-1',
#  972: '-1',
#  973: '-1',
#  974: '-1',
#  975: '-1',
#  976: '-1',
#  977: '-1',
#  978: '-1',
#  979: '-1',
#  980: '-1',
#  981: '-1',
#  982: '-1',
#  983: '-1',
#  984: '-1',
#  985: '-1',
#  986: '-1',
#  987: '-1',
#  988: '-1',
#  989: '-1',
#  990: '-1',
#  991: '-1',
#  992: '-1',
#  993: '-1',
#  994: '-1',
#  995: 'United States',
#  996: 'United States',
#  997: 'United States',
#  998: 'United States',
#  999: 'United States',
#  ...}

# %% [markdown]
# Dejo lo de transformar la proyeccion para el final.
# La solucion de dividir las eez en dos hemisferios funciona, pero cuando despues uso "intersection" para separar la parte continental de la maritima (que se usa para situal el punto identitario de cada eez en el centro de la parte continental) da problemas.

# %%
epsg_code = 54009
crs_proj = f"esri:{epsg_code}"

ContShape = gpd.read_file("../data/Continents/ref-coastline-2016-60m.shp/COAS_RG_60M_2016_4326.shp/COAS_RG_60M_2016_4326.shp", crs="epsg:4326")
# ContShape.to_crs("esri:54009", inplace=True)
# ContShape.plot(aspect=1)

EEZshapefile = gpd.read_file("../data/EEZ shapefile/EEZ_my_data.shp", crs="epgs:4326")
# EEZshapefile.crs = "epsg:4326"
EEZshapefile.plot(aspect=1)
# # Divide the world in two hemispheres to prevent the union of geometries that cross the antimeridian
# East_hemisphere = Polygon([(-180, -90), (0, -90), (0, 90), (-180, 90)])
# West_hemisphere = Polygon([(0, -90), (180, -90), (180, 90), (0, 90)])

# EEZshapefile_east = EEZshapefile.copy()
# EEZshapefile_east.crs = "epsg:4326"
# EEZshapefile_east.geometry = EEZshapefile.geometry.intersection(East_hemisphere)
# EEZshapefile_east.to_crs("esri:54009", inplace=True)

# EEZshapefile_west = EEZshapefile.copy()
# EEZshapefile_west.crs = "epsg:4326"
# EEZshapefile_west.geometry = EEZshapefile.geometry.intersection(West_hemisphere)
# EEZshapefile_west.to_crs("esri:54009", inplace=True)

# # Join the East and West hemispheres back together
# EEZshapefile_joined = EEZshapefile_east.copy()

# # for each row in the East hemisphere, find the corresponding row in the West hemisphere and union them
# for idx, row in EEZshapefile_joined.iterrows():
#     west_geom = EEZshapefile_west.iloc[idx].geometry
#     east_geom = EEZshapefile_east.iloc[idx].geometry
#     if west_geom.is_empty:
#         # set the geometry to the east geometry if the west geometry is empty
#         EEZshapefile_joined.at[idx, 'geometry'] = east_geom
#     elif east_geom.is_empty:
#         # set the geometry to the west geometry if the east geometry is empty
#         EEZshapefile_joined.at[idx, 'geometry'] = west_geom
#     else:
#         # union the two geometries

#         EEZshapefile_joined.at[idx, 'geometry'] = unary_union([east_geom, west_geom])

# EEZshapefile_joined.plot(aspect=1)

# EEZshapefile = EEZshapefile_joined
# Out:
# <Axes: >

# %%
EEZshapefile
# Out:
#     ISO_3digit                           Country Income  #Species       1/30d  \
# 0            -        Conflict zone Japan/Russia   None       3.0    0.068934
# 1            -   Conflict zone Japan/South Korea   None       NaN         NaN
# 2            -          Joint regime Japan/Korea   None       1.0    0.014620
# 3            -  Conflict zone China/Japan/Taiwan   None       NaN         NaN
# 4            -                   Spratly Islands   None       2.0    0.049715
# ..         ...                               ...    ...       ...         ...
# 257        SSD                       South Sudan      0       NaN         NaN
# 258        VTC                      Vatican City   None       NaN         NaN
# 259        ITA                             Italy      3       4.0    0.656769
# 260        KIR                          Kiribati      1       2.0    0.075248
# 261         -1                                -1   None      67.0  458.646594
#
#      err_1/30d  1/30d_sp                               continental_geometry  \
# 0     0.038081  0.022978  POLYGON ((149.15657 45.49545, 149.15924 45.486...
# 1          NaN       NaN  POLYGON ((134.22163 39.87854, 134.23452 39.539...
# 2     0.014426  0.014620  POLYGON ((126.24571 30.13314, 126.09167 30.303...
# 3          NaN       NaN  POLYGON ((122.90010 25.22988, 122.89410 25.255...
# 4     0.035857  0.024858  POLYGON ((112.23989 13.24707, 112.31403 13.297...
# ..         ...       ...                                                ...
# 257        NaN       NaN                                      POLYGON EMPTY
# 258        NaN       NaN                                      POLYGON EMPTY
# 259   0.291354  0.164192  MULTIPOLYGON (((13.80222 45.58639, 13.72157 45...
# 260   0.063740  0.037624  POLYGON ((-159.37462 7.91773, -159.37462 7.917...
# 261  56.119577  6.845472  MULTIPOLYGON (((-180.00000 -90.00000, -180.000...
#
#                                           EEZ_geometry  \
# 0    POLYGON ((149.15657 45.49545, 149.15924 45.486...
# 1    POLYGON ((134.22163 39.87854, 134.23452 39.539...
# 2    POLYGON ((126.24571 30.13314, 126.09167 30.303...
# 3    POLYGON ((122.90010 25.22988, 122.89410 25.255...
# 4    POLYGON ((112.23989 13.24707, 112.31403 13.297...
# ..                                                 ...
# 257  POLYGON ((34.09138 9.48753, 34.09416 9.45472, ...
# 258  POLYGON ((12.45669 41.90139, 12.45014 41.90089...
# 259  POLYGON ((12.13302 47.01256, 12.13611 46.96695...
# 260  POLYGON ((-159.37462 7.91773, -159.37462 7.917...
# 261  MULTIPOLYGON (((-180.00000 -90.00000, -180.000...
#
#                                        marine_geometry
# 0    POLYGON ((149.15657 45.49545, 149.15924 45.486...
# 1    POLYGON ((134.22163 39.87854, 134.23452 39.539...
# 2    POLYGON ((126.24571 30.13314, 126.09167 30.303...
# 3    POLYGON ((122.90010 25.22988, 122.89410 25.255...
# 4    POLYGON ((112.23989 13.24707, 112.31403 13.297...
# ..                                                 ...
# 257                                      POLYGON EMPTY
# 258                                      POLYGON EMPTY
# 259  MULTIPOLYGON (((13.80222 45.58639, 13.72157 45...
# 260  POLYGON ((-159.37462 7.91773, -159.37462 7.917...
# 261  MULTIPOLYGON (((-180.00000 -90.00000, -180.000...
#
# [262 rows x 10 columns]

# %%
EEZshapefile.set_geometry(EEZshapefile["marine_geometry"], crs="epsg:4326", inplace=True)
EEZshapefile.to_crs("esri:54009").plot(aspect=1)
# Out:
# <Axes: >

# %%
Continent_geometry = unary_union(ContShape.geometry)
EEZshapefile["continental_geometry"] = EEZshapefile.geometry.intersection(Continent_geometry)
EEZshapefile["EEZ_geometry"] = EEZshapefile.geometry
EEZshapefile["marine_geometry"] = EEZshapefile.geometry.difference(EEZshapefile.continental_geometry)
EEZshapefile.drop(columns="geometry", axis=1, inplace=True)
EEZshapefile.set_geometry("marine_geometry", inplace=True)

# %% [markdown]
# Ahora agrego los datos de comutacion entre celdas a eezs. Para eso traduzco las celdas a un int de eez y las agrego

# %%
df.groupby(['Taxon', 'T', "O05", "D05"]).agg({'ndispl':"sum"}).reset_index()
# Out:
#              Taxon  T     O05     D05  ndispl
# 0        Cetaceans  1   17249   17970       2
# 1        Cetaceans  1   17280   17998       1
# 2        Cetaceans  1   17968   17973       1
# 3        Cetaceans  1   17968   18689       1
# 4        Cetaceans  1   17969   17249       6
# ...            ... ..     ...     ...     ...
# 2408287    Turtles  5  238495  237060       4
# 2408288    Turtles  5  238495  237061      12
# 2408289    Turtles  5  238495  237062      12
# 2408290    Turtles  5  238495  237775      10
# 2408291    Turtles  5  239214  238495       3
#
# [2408292 rows x 5 columns]

# %%
df_eezs = df.copy()
df_eezs["O05"] = df["O05"].apply(lambda x: cells_to_eez[x])
df_eezs["D05"] = df["D05"].apply(lambda x: cells_to_eez[x])

# aggregate data that share Taxon, T, O05, D05 and sum the ndispl column
df_eezs_agg = df_eezs.groupby(["Taxon", "T", "O05", "D05"]).agg({'ndispl':"sum"}).reset_index()
display(df_eezs_agg)
# Out:
#            Taxon  T       O05         D05   ndispl
# 0      Cetaceans  1        -1          -1  1278343
# 1      Cetaceans  1        -1      Angola       20
# 2      Cetaceans  1        -1  Antarctica     2377
# 3      Cetaceans  1        -1   Argentina       23
# 4      Cetaceans  1        -1    Barbados        9
# ...          ... ..       ...         ...      ...
# 11655    Turtles  5    Zambia  Mozambique        6
# 11656    Turtles  5    Zambia      Zambia       77
# 11657    Turtles  5  Zimbabwe    Botswana       22
# 11658    Turtles  5  Zimbabwe  Mozambique        1
# 11659    Turtles  5  Zimbabwe    Zimbabwe       39
#
# [11660 rows x 5 columns]

# %%
# get the unique combinations of Taxon, T and O05 on the aggregated data
taxon_t_o05 = df_eezs_agg[["Taxon", "T", "O05"]].drop_duplicates()
# for each combinantion, compute the sum of ndispl for all the D05
# and normalize the ndispl column by the sum of ndispl for all the D05

df_eezs_agg_norm = df_eezs_agg.copy()
df_eezs_agg_norm["ndispl"] = df_eezs_agg_norm["ndispl"].astype(float)

for idx, row in taxon_t_o05.iterrows():
    columns_idx = (df_eezs_agg["Taxon"] == row["Taxon"]) & (df_eezs_agg["T"] == row["T"]) & (df_eezs_agg["O05"] == row["O05"])
    df_subset = df_eezs_agg[columns_idx].copy()
    sum_ndispl = df_subset["ndispl"].sum()
    df_eezs_agg_norm.loc[columns_idx, "ndispl"] = df_eezs_agg_norm.loc[columns_idx, "ndispl"] / sum_ndispl

display(df_eezs_agg_norm)

assert df_eezs_agg_norm["ndispl"].sum() == len(taxon_t_o05)
# Out:
#            Taxon  T       O05         D05    ndispl
# 0      Cetaceans  1        -1          -1  0.986508
# 1      Cetaceans  1        -1      Angola  0.000015
# 2      Cetaceans  1        -1  Antarctica  0.001834
# 3      Cetaceans  1        -1   Argentina  0.000018
# 4      Cetaceans  1        -1    Barbados  0.000007
# ...          ... ..       ...         ...       ...
# 11655    Turtles  5    Zambia  Mozambique  0.047619
# 11656    Turtles  5    Zambia      Zambia  0.611111
# 11657    Turtles  5  Zimbabwe    Botswana  0.354839
# 11658    Turtles  5  Zimbabwe  Mozambique  0.016129
# 11659    Turtles  5  Zimbabwe    Zimbabwe  0.629032
#
# [11660 rows x 5 columns]

# %%
df_eezs_agg_norm.loc[:, ["Taxon", "T", "O05", "D05", "ndispl"]].value_counts()
# Out:
# Taxon      T  O05         D05         ndispl
# Cetaceans  1  -1          -1          0.986508    1
# Seals      5  Algeria     Algeria     0.846154    1
#                           Libya       0.017094    1
#                           Niger       0.102564    1
#                           Portugal    0.017094    1
#                                                  ..
# Fishes     2  Antarctica  -1          0.020004    1
#                           Antarctica  0.979946    1
#                           Argentina   0.000010    1
#                           Chile       0.000041    1
# Turtles    5  Zimbabwe    Zimbabwe    0.629032    1
# Name: count, Length: 11660, dtype: int64

# %%
df_eezs_agg_norm.Taxon.unique()
# Out:
# array(['Cetaceans', 'Fishes', 'Seals', 'Turtles'], dtype=object)

# %%
11660 / 2915
# Out:
# 4.0

# %%
RepPoints = EEZshapefile.loc[:, ["Country", "continental_geometry"]].copy().set_geometry("continental_geometry", crs="epsg:4326")
RepPoints.geometry = RepPoints.geometry.representative_point() 
geodetic_lines = []
for i in range(len(RepPoints)):
    if RepPoints.geometry.iloc[i].is_empty:
        continue
    for j in range(i + 1, len(RepPoints)):
        if RepPoints.geometry.iloc[j].is_empty:
            continue
        source_country = RepPoints['Country'].iloc[i]
        target_country = RepPoints['Country'].iloc[j]
        source_geometry = RepPoints.geometry.iloc[i]
        target_geometry = RepPoints.geometry.iloc[j]
        geodetic_line = LineString([source_geometry, target_geometry])
        geodetic_lines.append([source_country + ";" + target_country, geodetic_line])

columns = ['Source Country;Target Country', 'geometry']
geodetic_gdf = gpd.GeoDataFrame(pd.DataFrame(geodetic_lines, columns=columns), geometry='geometry')
geodetic_gdf.crs = RepPoints.crs  # Set the same coordinate reference system as the original GeoDataFrame.
geodetic_gdf
# Out:
#                            Source Country;Target Country  \
# 0      Conflict zone Japan/Russia;Conflict zone China...
# 1             Conflict zone Japan/Russia;Spratly Islands
# 2      Conflict zone Japan/Russia;Protected zone Aust...
# 3                     Conflict zone Japan/Russia;Hungary
# 4                  Conflict zone Japan/Russia;Tajikistan
# ...                                                  ...
# 31873                              Vatican City;Kiribati
# 31874                                    Vatican City;-1
# 31875                                     Italy;Kiribati
# 31876                                           Italy;-1
# 31877                                        Kiribati;-1
#
#                                                 geometry
# 0      LINESTRING (148.72713 45.44850, 123.50161 25.8...
# 1      LINESTRING (148.72713 45.44850, 114.27580 11.1...
# 2      LINESTRING (148.72713 45.44850, 142.21384 -9.1...
# 3      LINESTRING (148.72713 45.44850, 19.13579 47.17...
# 4      LINESTRING (148.72713 45.44850, 70.94913 38.87...
# ...                                                  ...
# 31873  LINESTRING (12.45133 41.90540, -159.33152 3.90...
# 31874  LINESTRING (12.45133 41.90540, -179.99999 70.9...
# 31875  LINESTRING (12.75270 42.48800, -159.33152 3.90...
# 31876  LINESTRING (12.75270 42.48800, -179.99999 70.9...
# 31877  LINESTRING (-159.33152 3.90300, -179.99999 70....
#
# [31878 rows x 2 columns]

# %%
RepPoints.to_crs("esri:54009", inplace=True)
# create a list of pairs of coordinates using the x and y attributes of the representative points
points = [np.array([x, y], dtype=float) for x, y in zip(RepPoints.geometry.x.values, RepPoints.geometry.y.values)]
node_pos = dict(zip(RepPoints.Country, points))
node_pos
# Out:
# {'Conflict zone Japan/Russia': array([11953330.45728947,  5388830.04388244]),
#  'Conflict zone Japan/South Korea': array([nan, nan]),
#  'Joint regime Japan/Korea': array([nan, nan]),
#  'Conflict zone China/Japan/Taiwan': array([11599151.64459332,  3148476.93832822]),
#  'Spratly Islands': array([11320264.36785808,  1369471.89260175]),
#  'Joint regime Colombia/Jamaica': array([nan, nan]),
#  'Joint regime Nigeria/Sao Tome and Principe': array([nan, nan]),
#  'Joint development area Australia/East Timor': array([nan, nan]),
#  'Protected zone Australia/Papua New Guinea': array([14139779.7715322, -1134978.8897814]),
#  'Hungary': array([1507786.91846396, 5574259.6071918 ]),
#  'Tajikistan': array([6086851.39748524, 4662983.21203416]),
#  'Aruba': array([-6909627.10258763,  1542204.30924416]),
#  'Afghanistan': array([5820018.20312561, 4101391.15435315]),
#  'Angola': array([ 1861386.52230437, -1484923.90682713]),
#  'Anguilla': array([-6121831.94818554,  2236702.6310498 ]),
#  'Albania': array([1683564.03188134, 4915085.57235451]),
#  'Andorra': array([ 131064.7291757, 5072741.322637 ]),
#  'Netherlands Antilles': array([-6124213.37655278,  2144398.69909588]),
#  'United Arab Emirates': array([5205920.85600375, 2977842.45215973]),
#  'Argentina': array([-5573054.75633962, -4459534.94019728]),
#  'Armenia': array([3806227.01994194, 4797740.50627065]),
#  'American Samoa': array([-16785308.16961586,  -1764129.51002092]),
#  'Antarctica': array([ 2727067.07340568, -8257740.38715517]),
#  'French Southern & Antarctic Lands': array([ 5349752.19314268, -5794811.78135415]),
#  'Antigua & Barbuda': array([-6022190.60346439,  2098137.06564191]),
#  'Australia': array([12551904.76485998, -3018712.01080723]),
#  'Austria': array([1155648.78453432, 5631786.61099619]),
#  'Azerbaijan': array([4057417.43786831, 4808910.35135605]),
#  'Burundi': array([2996631.80201351, -417343.20062701]),
#  'Belgium': array([ 371600.29843913, 5926158.4232654 ]),
#  'Benin': array([ 228151.38531642, 1149302.06779619]),
#  'Bonaire, Sint-Eustasius, Saba': array([-6752066.71480537,  1513715.20883166]),
#  'Uruguay': array([-5031677.90805465, -3940589.77915639]),
#  'United States': array([-8641817.13160311,  4481573.8591248 ]),
#  'Uzbekistan': array([5315332.12785839, 4942941.43125762]),
#  'Saint Vincent and the Grenadines': array([-6030712.07493226,  1636545.46667915]),
#  'Venezuela': array([-6527715.90879219,   785526.89780335]),
#  'Virgin Islands, British': array([-6269334.52853476,  2259659.4781402 ]),
#  'Vietnam': array([10548188.77430511,  1970050.63317976]),
#  'Vanuatu': array([16365858.38069121, -1871181.85642679]),
#  'Wallis & Futuna': array([-17370956.33298191,  -1621492.66435963]),
#  'Samoa': array([-16981469.14678241,  -1677405.77132957]),
#  'Yemen': array([4645276.87218841, 1968687.1336847 ]),
#  'South Africa': array([ 2419060.66341236, -3462242.4596163 ]),
#  'Zambia': array([ 2509033.13509392, -1616593.50356942]),
#  'Zimbabwe': array([ 2841169.02359843, -2333686.57156224]),
#  'Paracel Islands': array([10959466.50093321,  2071515.17155411]),
#  'Area of overlap Australia/Indonesia': array([nan, nan]),
#  'Lesotho': array([ 2590565.99855985, -3597007.88281588]),
#  'Swaziland': array([ 2943665.94533409, -3234014.38725792]),
#  'Haiti': array([-6988175.2574516 ,  2331230.31131276]),
#  'Disputed Kenya/Somalia': array([4164019.59640177, -205353.2967029 ]),
#  'Disputed Western Sahara/Mauritania': array([nan, nan]),
#  'Disputed Barbados/Trinidad & Tobago': array([nan, nan]),
#  'Martinique': array([-5986791.02242768,  1802599.39678051]),
#  'United States Virgin Islands': array([-6306182.99743496,  2181268.12886528]),
#  'Area en controversia (disputed - Peruvian point of view)': array([nan, nan]),
#  'Russia': array([5799222.69198745, 6820145.7821313 ]),
#  'Svalbard': array([ 745511.3353655 , 8517910.78696935]),
#  'Norway': array([ 731945.28071314, 7295418.24003692]),
#  'South Sudan': array([2902017.46549915,  970608.46263696]),
#  'Vatican City': array([1038521.79870595, 5001244.29394874]),
#  'Italy': array([1057529.87196587, 5065554.95397748]),
#  'Kiribati': array([-15945786.29355848,    482442.89249129]),
#  '-1': array([-8867416.40443487,  7855157.08830668])}

# %%
# RepPoints.to_crs("esri:54009", inplace=True)
node_pos = dict(zip(RepPoints.Country,list(zip(RepPoints.geometry.x, RepPoints.geometry.y))))
# remove entries with nans in node_pos
node_pos = {k: v for k, v in node_pos.items() if not np.isnan(v[0]) and not np.isnan(v[1])}

# %%
node_pos
# Out:
# {'Conflict zone Japan/Russia': (11953330.45728947, 5388830.043882437),
#  'Conflict zone China/Japan/Taiwan': (11599151.64459332, 3148476.9383282196),
#  'Spratly Islands': (11320264.367858082, 1369471.8926017547),
#  'Protected zone Australia/Papua New Guinea': (14139779.771532197,
#   -1134978.8897813982),
#  'Hungary': (1507786.9184639566, 5574259.6071917955),
#  'Tajikistan': (6086851.397485237, 4662983.212034159),
#  'Aruba': (-6909627.102587632, 1542204.3092441629),
#  'Afghanistan': (5820018.20312561, 4101391.154353154),
#  'Angola': (1861386.5223043745, -1484923.9068271262),
#  'Anguilla': (-6121831.948185537, 2236702.631049805),
#  'Taiwan': (11475983.426849104, 2879604.615314164),
#  'Tanzania': (3426059.3353496315, -786439.6926349181),
#  'Uganda': (3275774.2870687186, 168683.1489206183),
#  'Ukraine': (2624981.943283642, 5709634.222546248),
#  'United States Minor Outlying Islands': (-16035216.08940654,
#   -43708.35408986925),
#  'Uruguay': (-5031677.90805465, -3940589.779156395),
#  'United States': (-8641817.13160311, 4481573.859124799),
#  'Uzbekistan': (5315332.127858386, 4942941.431257618),
#  'Saint Vincent and the Grenadines': (-6030712.074932259, 1636545.4666791481),
#  'Venezuela': (-6527715.908792195, 785526.8978033493),
#  'Virgin Islands, British': (-6269334.528534762, 2259659.478140199),
#  'Vietnam': (10548188.774305115, 1970050.633179763),
#  'Vanuatu': (16365858.380691212, -1871181.856426792),
#  'Wallis & Futuna': (-17370956.33298191, -1621492.6643596268),
#  'Samoa': (-16981469.146782413, -1677405.7713295685),
#  'Yemen': (4645276.872188405, 1968687.1336846966),
#  'South Africa': (2419060.6634123614, -3462242.4596163),
#  'Zambia': (2509033.135093917, -1616593.5035694218),
#  'Zimbabwe': (2841169.023598433, -2333686.5715622436),
#  'Paracel Islands': (10959466.500933208, 2071515.171554111),
#  'Lesotho': (2590565.998559848, -3597007.8828158835),
#  'Swaziland': (2943665.945334088, -3234014.387257925),
#  'Haiti': (-6988175.2574516, 2331230.3113127626),
#  'Disputed Kenya/Somalia': (4164019.5964017683, -205353.296702903),
#  'Martinique': (-5986791.022427683, 1802599.3967805123),
#  'United States Virgin Islands': (-6306182.997434957, 2181268.1288652783),
#  'Russia': (5799222.69198745, 6820145.782131299),
#  'Svalbard': (745511.335365497, 8517910.786969345),
#  'Norway': (731945.2807131389, 7295418.240036921),
#  'South Sudan': (2902017.4654991515, 970608.4626369583),
#  'Vatican City': (1038521.7987059548, 5001244.293948741),
#  'Italy': (1057529.871965874, 5065554.953977476),
#  'Kiribati': (-15945786.293558476, 482442.89249129035),
#  '-1': (-8867416.404434873, 7855157.088306677)}

# %%
list(node_pos.keys())
# Out:
# ['Conflict zone Japan/Russia',
#  'Conflict zone China/Japan/Taiwan',
#  'Spratly Islands',
#  'Protected zone Australia/Papua New Guinea',
#  'Hungary',
#  'Tajikistan',
#  'Aruba',
#  'Afghanistan',
#  'Angola',
#  'Anguilla',
#  'Albania',
#  'Andorra',
#  'Netherlands Antilles',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antarctica',
#  'French Southern & Antarctic Lands',
#  'Antigua & Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Bonaire, Sint-Eustasius, Saba',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'The Bahamas',
#  'Bosnia & Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei',
#  'Bhutan',
#  'Bouvet I.',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Cocos Is.',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, DRC',
#  'Congo',
#  'Cook Is.',
#  'Colombia',
#  'Comoros',
#  'Clipperton Island',
#  'Cape Verde',
#  'Costa Rica',
#  'Cuba',
#  'Curaçao',
#  'Christmas I.',
#  'Cayman Is.',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt',
#  'Eritrea',
#  'Western Sahara',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'Falkland Islands',
#  'France',
#  'Faroe Is.',
#  'Micronesia',
#  'Gabon',
#  'United Kingdom',
#  'Georgia',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Guinea',
#  'The Gambia',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Guadeloupe',
#  'Greece',
#  'Grenada',
#  'Greenland',
#  'Guatemala',
#  'French Guiana',
#  'Guyana',
#  'Heard I. & McDonald Is.',
#  'Honduras',
#  'Croatia',
#  'Indonesia',
#  'India',
#  'British Indian Ocean Territory',
#  'Ireland',
#  'Iran',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Jamaica',
#  'Jersey',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'St. Kitts & Nevis',
#  'South Korea',
#  'Kuwait',
#  'Laos',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'St. Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Saint Martin',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Madagascar',
#  'Maldives',
#  'Mexico',
#  'Marshall Is.',
#  'Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Montenegro',
#  'Mongolia',
#  'Northern Marinana Islands-Guam',
#  'Mozambique',
#  'Mauritania',
#  'Montserrat',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'Mayotte',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk I.',
#  'Nigeria',
#  'Nicaragua',
#  'Niue',
#  'Netherlands',
#  'Nepal',
#  'Nauru',
#  'New Zealand',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Pitcairn Is.',
#  'Peru',
#  'Philippines',
#  'Palau',
#  'Papua New Guinea',
#  'Poland',
#  'Puerto Rico',
#  'North Korea',
#  'Portugal',
#  'Paraguay',
#  'Gaza Strip',
#  'French Polynesia',
#  'Qatar',
#  'Reunion',
#  'Romania',
#  'Rwanda',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'South Georgia & the South Sandwich Is.',
#  'Saint Helena, Ascension en Tristan da Cunha',
#  'Jan Mayen',
#  'Solomon Is.',
#  'Sierra Leone',
#  'El Salvador',
#  'San Marino',
#  'Somalia',
#  'St. Pierre & Miquelon',
#  'Serbia',
#  'Sao Tome & Principe',
#  'Suriname',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Sint Maarten',
#  'Seychelles',
#  'Syria',
#  'Turks & Caicos Is.',
#  'Chad',
#  'Togo',
#  'Thailand',
#  'Tokelau',
#  'Turkmenistan',
#  'Timor-Leste',
#  'Tonga',
#  'Trinidad & Tobago',
#  'Tunisia',
#  'Turkey',
#  'Tuvalu',
#  'Taiwan',
#  'Tanzania',
#  'Uganda',
#  'Ukraine',
#  'United States Minor Outlying Islands',
#  'Uruguay',
#  'United States',
#  'Uzbekistan',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'Virgin Islands, British',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis & Futuna',
#  'Samoa',
#  'Yemen',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe',
#  'Paracel Islands',
#  'Lesotho',
#  'Swaziland',
#  'Haiti',
#  'Disputed Kenya/Somalia',
#  'Martinique',
#  'United States Virgin Islands',
#  'Russia',
#  'Svalbard',
#  'Norway',
#  'South Sudan',
#  'Vatican City',
#  'Italy',
#  'Kiribati',
#  '-1']

# %%
list_taxon = df_eezs_agg_norm["Taxon"].unique()
list_t = df_eezs_agg_norm["T"].unique()

taxon = "Cetaceans"
t= 1

for taxon in list_taxon:
    print(taxon)
    for t in list_t:
        print(t)
        
        G = nx.DiGraph()
        sources = df_eezs_agg_norm[(df_eezs_agg_norm["Taxon"] == taxon) & (df_eezs_agg_norm["T"] == t)]["O05"].unique()
        targets = df_eezs_agg_norm[(df_eezs_agg_norm["Taxon"] == taxon) & (df_eezs_agg_norm["T"] == t)]["D05"].unique()
        nodes = np.unique(np.concatenate([sources, targets]))

        G.add_nodes_from(nodes)

        for idx, row in df_eezs_agg_norm[(df_eezs_agg_norm["Taxon"] == taxon) & (df_eezs_agg_norm["T"] == t)].iterrows():
            G.add_edge(row["O05"], row["D05"], weight=row["ndispl"])

        # remove self loops
        G.remove_edges_from(nx.selfloop_edges(G))
        # remove node "-1"
        G.remove_node("-1")
        # remove nodes that are not in pos_node
        G.remove_nodes_from([node for node in G.nodes() if node not in node_pos])
        fig, ax = plt.subplots(figsize=(10,10), dpi=100)

        EEZshapefile.set_geometry("marine_geometry", inplace=True, crs="epsg:4326")
        EEZshapefile.to_crs("esri:54009").plot(aspect=1, edgecolor="#666666", facecolor="#444444", linewidth=0.1, ax=ax)
        EEZshapefile.set_geometry("continental_geometry", inplace=True, crs="epsg:4326")
        EEZshapefile.to_crs("esri:54009").plot(aspect=1, edgecolor="#666666", facecolor="white", linewidth=0.1, ax=ax)

        nx.draw_networkx_edges(G,
                               node_size=0,
                               pos=node_pos,
                               edge_color="red",
                               width=[G[u][v]['weight']*3 for u,v in G.edges()],
                               arrowstyle="->",
                               connectionstyle='arc3,rad=0.2',
                               ax=ax,
                               min_source_margin=0,
                               min_target_margin=0,)
        ax.axis("off")

        fig.savefig(f"../ERC data/images/{taxon}_{t}_days.png", dpi=300, bbox_inches="tight")
        fig.savefig(f"../ERC data/images/{taxon}_{t}_days.pdf", dpi=300, bbox_inches="tight")
# Out:
# Cetaceans
# 1
# 2
# 5
# Fishes
# 1
# 2
# 5
# Seals
# 1
# 2
# 5
# Turtles
# 1
# 2
# 5

# %%
[G[u][v]['weight'] for u,v in G.edges()]
# Out:
# [0.010934393638170975,
#  0.032803180914512925,
#  0.09045725646123261,
#  0.03777335984095427,
#  0.02286282306163022,
#  0.18181818181818182,
#  0.009523809523809525,
#  0.009523809523809525,
#  0.0380952380952381,
#  0.009523809523809525,
#  0.009523809523809525,
#  0.17647058823529413,
#  0.5882352941176471,
#  0.0392156862745098,
#  0.0213903743315508,
#  4.995404228110139e-06,
#  4.4958638052991246e-05,
#  0.002336448598130841,
#  0.08411214953271028,
#  0.030373831775700934,
#  0.007009345794392523,
#  0.13636363636363635,
#  0.09090909090909091,
#  0.022727272727272728,
#  0.1875,
#  0.4375,
#  0.375,
#  0.14285714285714285,
#  0.047619047619047616,
#  0.06140350877192982,
#  0.07017543859649122,
#  0.11403508771929824,
#  0.08771929824561403,
#  0.23529411764705882,
#  0.029411764705882353,
#  0.38235294117647056,
#  0.058823529411764705,
#  0.014705882352941176,
#  0.3235294117647059,
#  0.014705882352941176,
#  0.2033898305084746,
#  0.125,
#  0.0625,
#  0.32142857142857145,
#  0.10714285714285714,
#  0.15384615384615385,
#  0.038461538461538464,
#  0.14583333333333334,
#  0.19444444444444445,
#  0.027777777777777776,
#  0.06896551724137931,
#  0.3448275862068966,
#  0.034482758620689655,
#  0.05555555555555555,
#  0.5714285714285714,
#  0.42857142857142855,
#  0.2727272727272727,
#  0.18181818181818182,
#  0.008695652173913044,
#  0.034782608695652174,
#  0.0016891891891891893,
#  0.0016891891891891893,
#  0.0016891891891891893,
#  0.0016891891891891893,
#  0.2222222222222222,
#  0.7407407407407407,
#  0.0975609756097561,
#  0.0975609756097561,
#  0.012195121951219513,
#  0.036585365853658534,
#  1.0,
#  0.2,
#  0.04496216055794628,
#  0.016238868517548456,
#  0.020953378732320588,
#  0.0020953378732320588,
#  0.00995285489785228,
#  0.05133577789418544,
#  0.0007454033460327977,
#  0.00998472383266155,
#  0.006024096385542169,
#  0.006024096385542169,
#  0.030120481927710843,
#  0.02864363942712721,
#  0.007582139848357203,
#  0.002527379949452401,
#  0.060657118786857624,
#  0.004212299915754001,
#  0.051224944320712694,
